# %%
import beaapi

# %%
beakey = '664A2225-55B0-4262-B3CF-B5F1179E8322'

# %%
list_of_sets = beaapi.get_data_set_list(beakey)
display(list_of_sets)
# Out:
#                 DatasetName                                 DatasetDescription
# 0                      NIPA                               Standard NIPA tables
# 1        NIUnderlyingDetail               Standard NI underlying detail tables
# 2                       MNE                          Multinational Enterprises
# 3               FixedAssets                       Standard Fixed Assets tables
# 4                       ITA                International Transactions Accounts
# 5                       IIP                  International Investment Position
# 6               InputOutput                                  Input-Output Data
# 7             IntlServTrade                       International Services Trade
# 8               IntlServSTA  International Services Supplied Through Affili...
# 9             GDPbyIndustry                                    GDP by Industry
# 10                 Regional                                 Regional data sets
# ...

# %%
list_of_params = beaapi.get_parameter_list(beakey, 'NIPA')
display(list_of_params)
# Out:
#   ParameterName ParameterDataType  \
# 0     Frequency            string
# 1  ShowMillions            string
# 2       TableID           integer
# 3     TableName            string
# 4          Year           integer
#
#                                 ParameterDescription  ParameterIsRequiredFlag  \
# 0                 A - Annual, Q-Quarterly, M-Monthly                        1
# 1  A flag indicating that million-dollar data sho...                        0
# 2                 The standard NIPA table identifier                        0
# 3                      The new NIPA table identifier                        0
# 4    List of year(s) of data to retrieve (X for All)                        1
#
#   ParameterDefaultValue  MultipleAcceptedFlag AllValue
# 0                                           1
# 1                     N                     0
# 2                  <NA>                     0
# 3                  <NA>                     0
# ...

# %%
nipa_table_list = beaapi.get_parameter_values(beakey, 'NIPA', 'TableName')
display(nipa_table_list)
# Out:
#     TableName                                        Description
# 0      T10101  Table 1.1.1. Percent Change From Preceding Per...
# 1      T10102  Table 1.1.2. Contributions to Percent Change i...
# 2      T10103  Table 1.1.3. Real Gross Domestic Product, Quan...
# 3      T10104  Table 1.1.4. Price Indexes for Gross Domestic ...
# 4      T10105        Table 1.1.5. Gross Domestic Product (A) (Q)
# ..        ...                                                ...
# 320    T80106  Table 8.1.6. Real Gross Domestic Product, Chai...
# 321    T80111  Table 8.1.11. Real Gross Domestic Product: Per...
# 322    T80200  Table 8.2. Gross Domestic Income by Type of In...
# 323    T80300  Table 8.3. Federal Government Current Receipts...
# 324    T80400  Table 8.4. State and Local Government Current ...
#
# [325 rows x 2 columns]

# %%
bea_tbl = beaapi.get_data(beakey, datasetname='NIPA', TableName='T20600', Frequency='M', Year='X')
display(bea_tbl)
# Out:
#       TableName SeriesCode  LineNumber  \
# 0        T20600     A065RC           1
# 1        T20600     A065RC           1
# 2        T20600     A065RC           1
# 3        T20600     A065RC           1
# 4        T20600     A065RC           1
# ...         ...        ...         ...
# 33401    T20600     A067RM          43
# 33402    T20600     A067RM          43
# 33403    T20600     A067RM          43
# 33404    T20600     A067RM          43
# 33405    T20600     A067RM          43
#
#                                          LineDescription TimePeriod  \
# 0                                        Personal income    1959M01
# 1                                        Personal income    1959M02
# 2                                        Personal income    1959M03
# 3                                        Personal income    1959M04
# 4                                        Personal income    1959M05
# ...                                                  ...        ...
# ...

# %%
from sqlalchemy import create_engine


# Engine required to read or store data in a mysql database.
db_engine = create_engine(
    "mysql://{user}:{pw}@localhost/{db}"
    .format(user="root",
    pw="rootroot",
    db="capstone"))

# Store each dataframe in the data base capstone with the table name listed in the call.
bea_tbl.to_sql(con=db_engine, name='personal_income_monthly', if_exists='replace', index=False)
# Out:
# 33406

# %%
unipa_table_list = beaapi.get_parameter_values(beakey, 'NIUnderlyingDetail', 'TableName')
display(unipa_table_list)
# Out:
#    TableName                                        Description
# 0      U001A  Table 1AU. Real Manufacturing and Trade Invent...
# 1     U001A2  Table 1AU2. Real Manufacturing and Trade Inven...
# 2      U001B  Table 1BU. Real Manufacturing and Trade Invent...
# 3     U001BC  Table 1BUC. Current Dollar Manufacturing and T...
# 4     U002AU  Table 2AU. Real Manufacturing and Trade Sales,...
# ..       ...                                                ...
# 66    U90100  Table 9.1U. Reconciliation of Percent Change i...
# 67    U90200  Table 9.2U. Final Sales of Domestic Computers ...
# 68    U90300  Table 9.3U. Gross Domestic Product and Final S...
# 69    U90400     Table 9.4U. Software investment and prices (A)
# 70    U90500  Table 9.5U. Contributions to Percent Change in...
#
# [71 rows x 2 columns]

# %%
regional_table_list = beaapi.get_parameter_values(beakey, 'Regional', 'TableName')
display(regional_table_list)
# Out:
#            Key                                               Desc
# 0     CAEMP25N  Total full-time and part-time employment by NA...
# 1     CAEMP25S  Total full-time and part-time employment by SI...
# 2       CAGDP1  County and MSA gross domestic product (GDP) su...
# 3      CAGDP11        Contributions to percent change in real GDP
# 4       CAGDP2  Gross domestic product (GDP) by county and met...
# ..         ...                                                ...
# 89     SQINC7H        Wages and salaries by industry (historical)
# 90     SQINC7N               Wages and salaries by NAICS industry
# 91     SQINC7S                 Wages and salaries by SIC industry
# 92  TASUMMARY1  Summary of GDP and components for U.S. territo...
# 93  TASUMMARY2  Summary of real GDP and components for U.S. te...
#
# [94 rows x 2 columns]

# %%
list_of_param_vals_T = beaapi.get_parameter_values(beakey, 'NIPA', 'TableName')
display(list_of_param_vals)

# %%
gov_receipts_expenditures_tbl = beaapi.get_data(beakey, datasetname='NIPA', TableName='T30100', Frequency='Q', Year='X')
display(gov_receipts_expenditures_tbl)
# Out:
#       TableName SeriesCode  LineNumber                   LineDescription  \
# 0        T30100     W021RC           1                  Current receipts
# 1        T30100     W021RC           1                  Current receipts
# 2        T30100     W021RC           1                  Current receipts
# 3        T30100     W021RC           1                  Current receipts
# 4        T30100     W021RC           1                  Current receipts
# ...         ...        ...         ...                               ...
# 12509    T30100     AD01RC          43  Net lending or net borrowing (-)
# 12510    T30100     AD01RC          43  Net lending or net borrowing (-)
# 12511    T30100     AD01RC          43  Net lending or net borrowing (-)
# 12512    T30100     AD01RC          43  Net lending or net borrowing (-)
# 12513    T30100     AD01RC          43  Net lending or net borrowing (-)
#
#       TimePeriod      METRIC_NAME CL_UNIT  UNIT_MULT  DataValue NoteRef
# ...

# %%
# Store each dataframe in the data base capstone with the table name listed in the call.
gov_receipts_expenditures_tbl.to_sql(con=db_engine, name='government_expenditures', if_exists='replace', index=False)
# Out:
# 12514

# %%
national_income_by_industry_tbl = beaapi.get_data(beakey, datasetname='NIPA', TableName='T60100B', Frequency='Q', Year='X')
display(national_income_by_industry_tbl)
# Out:
#      TableName SeriesCode  LineNumber  \
# 0      T60100B     A422RC           1
# 1      T60100B     A422RC           1
# 2      T60100B     A422RC           1
# 3      T60100B     A422RC           1
# 4      T60100B     A422RC           1
# ...        ...        ...         ...
# 3035   T60100B     A192RC          19
# 3036   T60100B     A192RC          19
# 3037   T60100B     A192RC          19
# 3038   T60100B     A192RC          19
# 3039   T60100B     A192RC          19
#
#                                         LineDescription TimePeriod  \
# 0     National income without capital consumption ad...     1948Q1
# 1     National income without capital consumption ad...     1948Q2
# 2     National income without capital consumption ad...     1948Q3
# 3     National income without capital consumption ad...     1948Q4
# 4     National income without capital consumption ad...     1949Q1
# ...                                                 ...        ...
# ...

# %%
national_income_by_industry_c_tbl = beaapi.get_data(beakey, datasetname='NIPA', TableName='T60100C', Frequency='Q', Year='X')
display(national_income_by_industry_c_tbl)
# Out:
#      TableName SeriesCode  LineNumber  \
# 0      T60100C     A422RC           1
# 1      T60100C     A422RC           1
# 2      T60100C     A422RC           1
# 3      T60100C     A422RC           1
# 4      T60100C     A422RC           1
# ...        ...        ...         ...
# 1059   T60100C     A192RC          19
# 1060   T60100C     A192RC          19
# 1061   T60100C     A192RC          19
# 1062   T60100C     A192RC          19
# 1063   T60100C     A192RC          19
#
#                                         LineDescription TimePeriod  \
# 0     National income without capital consumption ad...     1987Q1
# 1     National income without capital consumption ad...     1987Q2
# 2     National income without capital consumption ad...     1987Q3
# 3     National income without capital consumption ad...     1987Q4
# 4     National income without capital consumption ad...     1988Q1
# ...                                                 ...        ...
# ...

# %%
national_income_by_industry_d_tbl = beaapi.get_data(beakey, datasetname='NIPA', TableName='T60100D', Frequency='Q', Year='X')
display(national_income_by_industry_d_tbl)
# Out:
#      TableName SeriesCode  LineNumber  \
# 0      T60100D     A422RC           1
# 1      T60100D     A422RC           1
# 2      T60100D     A422RC           1
# 3      T60100D     A422RC           1
# 4      T60100D     A422RC           1
# ...        ...        ...         ...
# 1906   T60100D     A192RC          21
# 1907   T60100D     A192RC          21
# 1908   T60100D     A192RC          21
# 1909   T60100D     A192RC          21
# 1910   T60100D     A192RC          21
#
#                                         LineDescription TimePeriod  \
# 0     National income without capital consumption ad...     2001Q1
# 1     National income without capital consumption ad...     2001Q2
# 2     National income without capital consumption ad...     2001Q3
# 3     National income without capital consumption ad...     2001Q4
# 4     National income without capital consumption ad...     2002Q1
# ...                                                 ...        ...
# ...

# %%
gov_re

# %%
# Engine required to read or store data in a mysql database.
db_engine = create_engine(
    "mysql://{user}:{pw}@localhost/{db}"
    .format(user="root",
    pw="rootroot",
    db="capstone"))

# Store each dataframe in the data base capstone with the table name listed in the call.
national_income_by_industry_tbl.to_sql(con=db_engine, name='ni_by_industry', if_exists='replace', index=False)
national_income_by_industry_c_tbl.to_sql(con=db_engine, name='ni_by_industry',  if_exists='append', index=False)
national_income_by_industry_d_tbl.to_sql(con=db_engine, name='ni_by_industry', if_exists='append', index=False)
# Out:
# 1911
